# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
AV = AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename = "housing.csv"
dft = AV.AutoViz(filename)
# Out:
# Shape of your Data Set loaded: (489, 4)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  4
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     4 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_0d462_row0_col0, #T_0d462_row0_col2, #T_0d462_row0_col5, #T_0d462_row1_col0, #T_0d462_row1_col2, #T_0d462_row1_col5, #T_0d462_row2_col0, #T_0d462_row2_col2, #T_0d462_row2_col5, #T_0d462_row3_col0, #T_0d462_row3_col2, #T_0d462_row3_col5 {
#   font-family: Segoe UI;
# }
# #T_0d462_row0_col1, #T_0d462_row0_col3, #T_0d462_row0_col4, #T_0d462_row1_col1, #T_0d462_row1_col3, #T_0d462_row1_col4, #T_0d462_row2_col1, #T_0d462_row2_col3, #T_0d462_row2_col4, #T_0d462_row3_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0d462_row3_col3, #T_0d462_row3_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_0d462">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d462_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_0d462_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_0d462_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_0d462_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_0d462_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_0d462_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d462_level0_row0" class="row_heading level0 row0" >RM</th>
#       <td id="T_0d462_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_0d462_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_0d462_row0_col2" class="data row0 col2" >NA</td>
#       <td id="T_0d462_row0_col3" class="data row0 col3" >3.561000</td>
#       <td id="T_0d462_row0_col4" class="data row0 col4" >8.398000</td>
#       <td id="T_0d462_row0_col5" class="data row0 col5" >Column has 22 outliers greater than upper bound (7.62) or lower than lower bound(4.84). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_0d462_level0_row1" class="row_heading level0 row1" >LSTAT</th>
#       <td id="T_0d462_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_0d462_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_0d462_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_0d462_row1_col3" class="data row1 col3" >1.980000</td>
#       <td id="T_0d462_row1_col4" class="data row1 col4" >37.970000</td>
#       <td id="T_0d462_row1_col5" class="data row1 col5" >Column has 7 outliers greater than upper bound (31.75) or lower than lower bound(-7.25). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_0d462_level0_row2" class="row_heading level0 row2" >PTRATIO</th>
#       <td id="T_0d462_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_0d462_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_0d462_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_0d462_row2_col3" class="data row2 col3" >12.600000</td>
#       <td id="T_0d462_row2_col4" class="data row2 col4" >22.000000</td>
#       <td id="T_0d462_row2_col5" class="data row2 col5" >Column has 13 outliers greater than upper bound (24.40) or lower than lower bound(13.20). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_0d462_level0_row3" class="row_heading level0 row3" >MEDV</th>
#       <td id="T_0d462_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_0d462_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_0d462_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_0d462_row3_col3" class="data row3 col3" >105000.000000</td>
#       <td id="T_0d462_row3_col4" class="data row3 col4" >1024800.000000</td>
#       <td id="T_0d462_row3_col5" class="data row3 col5" >Column has 22 outliers greater than upper bound (770700.00) or lower than lower bound(98700.00). Cap them or remove them.</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 10
# All Plots done
# Time to run AutoViz = 4 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.3.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sweetviz) (2.2.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sweetviz) (2.3.0)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sweetviz) (3.10.0)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sweetviz) (4.67.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sweetviz) (1.15.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sweetviz) (3.1.5)
# Collecting importlib-resources>=1.2.0 (from sweetviz)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Requirement already satisfied: colorama in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Downloading sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/15.1 MB 4.2 MB/s eta 0:00:04
#    ------ --------------------------------- 2.4/15.1 MB 5.4 MB/s eta 0:00:03
#    ------ --------------------------------- 2.4/15.1 MB 5.4 MB/s eta 0:00:03
#    ------ --------------------------------- 2.6/15.1 MB 2.8 MB/s eta 0:00:05
#    -------- ------------------------------- 3.1/15.1 MB 2.7 MB/s eta 0:00:05
#    --------- ------------------------------ 3.7/15.1 MB 2.7 MB/s eta 0:00:05
#    ------------ --------------------------- 4.7/15.1 MB 2.9 MB/s eta 0:00:04
#    --------------- ------------------------ 6.0/15.1 MB 3.4 MB/s eta 0:00:03
#    -------------------- ------------------- 7.9/15.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 9.4/15.1 MB 4.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.7/15.1 MB 4.5 MB/s eta 0:00:01
#    -------------------------------- ------- 12.3/15.1 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 13.6/15.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 15.1/15.1 MB 4.0 MB/s eta 0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Installing collected packages: importlib-resources, sweetviz
#
#    ---------------------------------------- 0/2 [importlib-resources]
#    -------------------- ------------------- 1/2 [sweetviz]
#    -------------------- ------------------- 1/2 [sweetviz]
#    -------------------- ------------------- 1/2 [sweetviz]
#    ---------------------------------------- 2/2 [sweetviz]
#
# Successfully installed importlib-resources-6.5.2 sweetviz-2.3.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)

# %%
import seaborn as sns

df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass   sex     age  sibsp  parch   fare   embarked  class   \
# 0        0        3      male  22.0    1      0     7.2500     S      Third
# 1        1        1    female  38.0    1      0    71.2833     C      First
# 2        1        3    female  26.0    0      0     7.9250     S      Third
# 3        1        1    female  35.0    1      0    53.1000     S      First
# 4        0        3      male  35.0    0      0     8.0500     S      Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886      0        2      male  27.0    0      0    13.0000     S     Second
# 887      1        1    female  19.0    0      0    30.0000     S      First
# 888      0        3    female   NaN    1      2    23.4500     S      Third
# 889      1        1      male  26.0    0      0    30.0000     C      First
# 890      0        3      male  32.0    0      0     7.7500     Q      Third
#
#      who    adult_male deck embark_town  alive  alone
# 0      man      True    NaN  Southampton    no  False
# 1    woman     False      C    Cherbourg   yes  False
# 2    woman     False    NaN  Southampton   yes   True
# 3    woman     False      C  Southampton   yes  False
# 4      man      True    NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man      True    NaN  Southampton    no   True
# 887  woman     False      B  Southampton   yes   True
# 888  woman     False    NaN  Southampton    no  False
# 889    man      True      C    Cherbourg   yes   True
# 890    man      True    NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
import sweetviz as sv
my_report = sv.analyze(df)
my_report.show_html()
# Out:
# Feature: age                                 |██▌       | [ 25%]   02:27 -> (07:23 left)
# Feature: age                                 |██▌       | [ 25%]   00:00 -> (00:01 left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 import sweetviz as sv
# ----> 2 my_report = sv.analyze(df)
#       3 my_report.show_html()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sweetviz\sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sweetviz\dataframe_report.py:277, in DataframeReport.__init__(self, source, target_feature_name, compare, pairwise_analysis, fc, verbosity)
#     274 for f in features_to_process:
#     275     # start = time.perf_counter()
#     276     self.progress_bar.set_description_str(f"Feature: {f.source.name}")
# --> 277     self._features[f.source.name] = sa.analyze_feature_to_dictionary(f)
#     278     self.progress_bar.update(1)
#     279     # print(f"DONE FEATURE------> {f.source.name}"
#     280     #       f" {(time.perf_counter() - start):.2f}   {self._features[f.source.name]['type']}")
#     281 # self.progress_bar.set_description_str('[FEATURES DONE]')
#     282 # self.progress_bar.close()
#     283
#     284 # Wrap up summary
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sweetviz\series_analyzer.py:142, in analyze_feature_to_dictionary(to_process)
#     140 # Perform full analysis on source/compare/target
#     141 if returned_feature_dict["type"] == FeatureType.TYPE_NUM:
# --> 142     sweetviz.series_analyzer_numeric.analyze(to_process, returned_feature_dict)
#     143 elif returned_feature_dict["type"] == FeatureType.TYPE_CAT:
#     144     sweetviz.series_analyzer_cat.analyze(to_process, returned_feature_dict)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sweetviz\series_analyzer_numeric.py:102, in analyze(to_process, feature_dict)
#      98     do_stats_numeric(to_process.compare, compare_dict)
#     100 do_detail_numeric(to_process.source, to_process.source_counts, to_process.compare_counts, feature_dict)
# --> 102 feature_dict["minigraph"] = GraphNumeric("mini", to_process)
#     103 feature_dict["detail_graphs"] = list()
#     104 for num_bins in [0, 5, 15, 30]:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sweetviz\graph_numeric.py:71, in GraphNumeric.__init__(self, which_graph, to_process)
#      67     normalizing_weights = norm_source
#      69 gap_percent = config["Graphs"].getfloat("summary_graph_categorical_gap")
# ---> 71 warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)
#      72 self.hist_specs = axs.hist(plot_data, weights = normalizing_weights, bins=self.num_bins, \
#      73                            rwidth = (100.0 - gap_percent) / 100.0)
#      74 warnings.filterwarnings('once', category=np.VisibleDeprecationWarning)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\__init__.py:808, in __getattr__(attr)
#     805     import numpy.char as char
#     806     return char.chararray
# --> 808 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'VisibleDeprecationWarning'

# %%
pip install numpy==1.23.5
# Out:
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# Downloading numpy-1.23.5-cp311-cp311-win_amd64.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.6 MB 840.2 kB/s eta 0:00:17
#    -- ------------------------------------- 1.0/14.6 MB 1.3 MB/s eta 0:00:11
#    --- ------------------------------------ 1.3/14.6 MB 1.5 MB/s eta 0:00:09
#    ------ --------------------------------- 2.4/14.6 MB 2.0 MB/s eta 0:00:07
#    -------- ------------------------------- 3.1/14.6 MB 2.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.9/14.6 MB 2.5 MB/s eta 0:00:05
#    ------------- -------------------------- 5.0/14.6 MB 2.8 MB/s eta 0:00:04
#    --------------- ------------------------ 5.8/14.6 MB 3.1 MB/s eta 0:00:03
#    ------------------- -------------------- 7.1/14.6 MB 3.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.4/14.6 MB 3.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.4/14.6 MB 3.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 8.7/14.6 MB 3.2 MB/s eta 0:00:02
#    -------------------------- ------------- 9.7/14.6 MB 3.2 MB/s eta 0:00:02
#    ------------------------------ --------- 11.0/14.6 MB 3.4 MB/s eta 0:00:02
#    -------------------------------- ------- 12.1/14.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 3.5 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.0
#     Uninstalling numpy-2.3.0:
#       Successfully uninstalled numpy-2.3.0
# Successfully installed numpy-1.23.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\~~mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\~~mpy'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autoviz 0.1.905 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 1.23.5 which is incompatible.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.5.1 which is incompatible.
# ydata-profiling 4.16.1 requires visions[type_image_path]<0.8.2,>=0.7.5, but you have visions 0.7.4 which is incompatible.

# %%
pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-3.17.0-py2.py3-none-any.whl.metadata (16 kB)
# Collecting dash-daq<=0.5.0 (from dtale)
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ---------------- ----------------------- 262.1/642.7 kB ? eta -:--:--
#      -------------------------------------- 642.7/642.7 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting future>=0.14.0 (from dtale)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: missingno in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (0.5.2)
# Requirement already satisfied: pandas in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (2.2.3)
# Collecting squarify (from dtale)
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Collecting strsimpy (from dtale)
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: xlrd in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (2.0.1)
# Collecting beautifulsoup4!=4.13.0b2 (from dtale)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: certifi in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (2024.8.30)
# Collecting dash-bootstrap-components<=1.7.1 (from dtale)
#   Downloading dash_bootstrap_components-1.7.1-py3-none-any.whl.metadata (17 kB)
# Collecting lz4 (from dtale)
#   Downloading lz4-4.4.4-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: cycler in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (0.12.1)
# Collecting dash<=2.18.2 (from dtale)
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: seaborn in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (0.13.2)
# Requirement already satisfied: werkzeug in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (3.1.3)
# Collecting Flask-Compress (from dtale)
#   Downloading Flask_Compress-1.17-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: scikit-learn in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (1.7.0)
# Requirement already satisfied: statsmodels in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (0.14.4)
# Requirement already satisfied: networkx in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (3.4.2)
# Requirement already satisfied: numpy in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (1.23.5)
# Requirement already satisfied: openpyxl!=3.2.0b1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (3.1.5)
# Collecting xarray (from dtale)
#   Downloading xarray-2025.6.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (1.15.3)
# Requirement already satisfied: et-xmlfile in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (2.0.0)
# Requirement already satisfied: plotly in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (6.1.2)
# Requirement already satisfied: Flask in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (3.1.1)
# Requirement already satisfied: itsdangerous in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (2.2.0)
# Requirement already satisfied: requests in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (2.32.3)
# Collecting kaleido (from dtale)
#   Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dtale) (3.10.0)
# Collecting Flask (from dtale)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting werkzeug (from dtale)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting dash-html-components==2.0.0 (from dash<=2.18.2->dtale)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash<=2.18.2->dtale)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash<=2.18.2->dtale)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash<=2.18.2->dtale)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash<=2.18.2->dtale) (4.12.2)
# Collecting retrying (from dash<=2.18.2->dtale)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dash<=2.18.2->dtale) (1.6.0)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from dash<=2.18.2->dtale) (65.5.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask->dtale) (3.1.5)
# Requirement already satisfied: click>=8.1.3 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask->dtale) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask->dtale) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug->dtale) (2.1.5)
# Collecting soupsieve>1.2 (from beautifulsoup4!=4.13.0b2->dtale)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: colorama in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=8.1.3->Flask->dtale) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly->dtale) (1.20.1)
# Requirement already satisfied: packaging in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly->dtale) (24.2)
# Collecting brotli (from Flask-Compress->dtale)
#   Downloading Brotli-1.1.0-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting zstandard (from Flask-Compress->dtale)
#   Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting zipp>=3.20 (from importlib-metadata->dash<=2.18.2->dtale)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->dtale) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->dtale) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->dtale) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->dtale) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->dtale) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->dtale) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->dtale) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->dtale) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->dtale) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->dtale) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->dtale) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels->dtale) (1.0.1)
# Collecting numpy (from dtale)
#   Using cached numpy-2.3.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Downloading dtale-3.17.0-py2.py3-none-any.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.9 MB 2.8 MB/s eta 0:00:06
#    -- ------------------------------------- 1.0/14.9 MB 3.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.3/14.9 MB 2.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/14.9 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.1/14.9 MB 2.1 MB/s eta 0:00:07
#    ------- -------------------------------- 2.9/14.9 MB 2.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.2/14.9 MB 2.9 MB/s eta 0:00:04
#    ------------- -------------------------- 5.0/14.9 MB 3.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.3/14.9 MB 3.5 MB/s eta 0:00:03
#    --------------------- ------------------ 7.9/14.9 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 9.2/14.9 MB 4.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.5/14.9 MB 4.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.0/14.9 MB 4.2 MB/s eta 0:00:01
#    -------------------------------- ------- 12.1/14.9 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.1/14.9 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.9 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.9 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.9 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.9 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 3.6 MB/s eta 0:00:00
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.8 MB 4.8 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/7.8 MB 5.9 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/7.8 MB 4.6 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/7.8 MB 4.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/7.8 MB 4.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.8/7.8 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/7.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 3.9 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading dash_bootstrap_components-1.7.1-py3-none-any.whl (229 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading Flask_Compress-1.17-py3-none-any.whl (8.7 kB)
# Downloading Brotli-1.1.0-cp311-cp311-win_amd64.whl (357 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
#    ---------------------------------------- 0.0/65.9 MB ? eta -:--:--
#     --------------------------------------- 1.3/65.9 MB 7.5 MB/s eta 0:00:09
#    - -------------------------------------- 2.9/65.9 MB 7.6 MB/s eta 0:00:09
#    -- ------------------------------------- 3.9/65.9 MB 6.7 MB/s eta 0:00:10
#    --- ------------------------------------ 5.0/65.9 MB 6.3 MB/s eta 0:00:10
#    --- ------------------------------------ 5.5/65.9 MB 5.7 MB/s eta 0:00:11
#    --- ------------------------------------ 6.6/65.9 MB 5.2 MB/s eta 0:00:12
#    ---- ----------------------------------- 7.3/65.9 MB 5.0 MB/s eta 0:00:12
#    ----- ---------------------------------- 8.7/65.9 MB 5.1 MB/s eta 0:00:12
#    ------ --------------------------------- 10.0/65.9 MB 5.2 MB/s eta 0:00:11
#    ------ --------------------------------- 11.3/65.9 MB 5.3 MB/s eta 0:00:11
#    ------- -------------------------------- 12.3/65.9 MB 5.3 MB/s eta 0:00:11
#    -------- ------------------------------- 13.4/65.9 MB 5.2 MB/s eta 0:00:11
#    -------- ------------------------------- 13.9/65.9 MB 5.1 MB/s eta 0:00:11
#    --------- ------------------------------ 15.5/65.9 MB 5.2 MB/s eta 0:00:10
#    ---------- ----------------------------- 16.8/65.9 MB 5.3 MB/s eta 0:00:10
#    ---------- ----------------------------- 17.8/65.9 MB 5.3 MB/s eta 0:00:10
#    ----------- ---------------------------- 19.4/65.9 MB 5.4 MB/s eta 0:00:09
#    ------------ --------------------------- 20.4/65.9 MB 5.4 MB/s eta 0:00:09
#    ------------- -------------------------- 21.5/65.9 MB 5.4 MB/s eta 0:00:09
#    ------------- -------------------------- 22.3/65.9 MB 5.3 MB/s eta 0:00:09
#    ------------- -------------------------- 23.1/65.9 MB 5.3 MB/s eta 0:00:09
#    -------------- ------------------------- 24.1/65.9 MB 5.2 MB/s eta 0:00:09
#    --------------- ------------------------ 24.9/65.9 MB 5.1 MB/s eta 0:00:08
#    --------------- ------------------------ 25.7/65.9 MB 5.1 MB/s eta 0:00:08
#    ---------------- ----------------------- 27.0/65.9 MB 5.1 MB/s eta 0:00:08
#    ---------------- ----------------------- 27.8/65.9 MB 5.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 28.8/65.9 MB 5.1 MB/s eta 0:00:08
#    ------------------ --------------------- 30.1/65.9 MB 5.1 MB/s eta 0:00:08
#    ------------------- -------------------- 31.5/65.9 MB 5.1 MB/s eta 0:00:07
#    -------------------- ------------------- 33.0/65.9 MB 5.2 MB/s eta 0:00:07
#    -------------------- ------------------- 34.3/65.9 MB 5.3 MB/s eta 0:00:06
#    --------------------- ------------------ 35.9/65.9 MB 5.3 MB/s eta 0:00:06
#    ---------------------- ----------------- 37.2/65.9 MB 5.4 MB/s eta 0:00:06
#    ----------------------- ---------------- 38.8/65.9 MB 5.4 MB/s eta 0:00:06
#    ------------------------ --------------- 40.1/65.9 MB 5.4 MB/s eta 0:00:05
#    ------------------------ --------------- 41.2/65.9 MB 5.4 MB/s eta 0:00:05
#    ------------------------- -------------- 41.9/65.9 MB 5.4 MB/s eta 0:00:05
#    -------------------------- ------------- 43.0/65.9 MB 5.4 MB/s eta 0:00:05
#    -------------------------- ------------- 43.8/65.9 MB 5.3 MB/s eta 0:00:05
#    -------------------------- ------------- 44.3/65.9 MB 5.2 MB/s eta 0:00:05
#    --------------------------- ------------ 45.1/65.9 MB 5.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 46.4/65.9 MB 5.2 MB/s eta 0:00:04
#    ---------------------------- ----------- 46.9/65.9 MB 5.2 MB/s eta 0:00:04
#    ----------------------------- ---------- 48.2/65.9 MB 5.2 MB/s eta 0:00:04
#    ----------------------------- ---------- 48.8/65.9 MB 5.2 MB/s eta 0:00:04
#    ----------------------------- ---------- 48.8/65.9 MB 5.2 MB/s eta 0:00:04
#    ------------------------------ --------- 50.1/65.9 MB 5.0 MB/s eta 0:00:04
#    ------------------------------ --------- 50.6/65.9 MB 5.0 MB/s eta 0:00:04
#    ------------------------------- -------- 51.4/65.9 MB 4.9 MB/s eta 0:00:03
#    ------------------------------- -------- 52.2/65.9 MB 4.9 MB/s eta 0:00:03
#    -------------------------------- ------- 53.0/65.9 MB 4.9 MB/s eta 0:00:03
#    -------------------------------- ------- 53.5/65.9 MB 4.8 MB/s eta 0:00:03
#    -------------------------------- ------- 54.0/65.9 MB 4.8 MB/s eta 0:00:03
#    --------------------------------- ------ 54.8/65.9 MB 4.8 MB/s eta 0:00:03
#    --------------------------------- ------ 55.6/65.9 MB 4.8 MB/s eta 0:00:03
#    ---------------------------------- ----- 56.4/65.9 MB 4.7 MB/s eta 0:00:03
#    ---------------------------------- ----- 57.1/65.9 MB 4.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 58.2/65.9 MB 4.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 59.2/65.9 MB 4.7 MB/s eta 0:00:02
#    ------------------------------------ --- 60.3/65.9 MB 4.7 MB/s eta 0:00:02
#    ------------------------------------- -- 61.1/65.9 MB 4.7 MB/s eta 0:00:02
#    ------------------------------------- -- 62.1/65.9 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 62.9/65.9 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 64.0/65.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  64.7/65.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  65.8/65.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  65.8/65.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  65.8/65.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  65.8/65.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  65.8/65.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  65.8/65.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  65.8/65.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 65.9/65.9 MB 4.3 MB/s eta 0:00:00
# Downloading lz4-4.4.4-cp311-cp311-win_amd64.whl (99 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Downloading xarray-2025.6.1-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------------------------------- -------- 1.0/1.3 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 4.5 MB/s eta 0:00:00
# Using cached numpy-2.3.0-cp311-cp311-win_amd64.whl (13.0 MB)
# Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl (495 kB)
# Building wheels for collected packages: dash-daq
#   Building wheel for dash-daq (setup.py): started
#   Building wheel for dash-daq (setup.py): finished with status 'done'
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669715 sha256=a026859781e0f360a1c5640021ffd34a542823cda7bbbe1c96be154a43ef912e
#   Stored in directory: c:\users\agupta31\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\9a\e1\a3\ef7c3fa914e4df214fdcb64529c44669e3e72ebdb784db10e0
# Successfully built dash-daq
# Installing collected packages: strsimpy, squarify, kaleido, dash-table, dash-html-components, dash-core-components, brotli, zstandard, zipp, werkzeug, soupsieve, retrying, numpy, lz4, future, importlib-metadata, Flask, beautifulsoup4, xarray, Flask-Compress, dash, dash-daq, dash-bootstrap-components, dtale
#
#    ----------------------------------------  0/24 [strsimpy]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    --- ------------------------------------  2/24 [kaleido]
#    ----------- ----------------------------  7/24 [zstandard]
#   Attempting uninstall: werkzeug
#    ----------- ----------------------------  7/24 [zstandard]
#     Found existing installation: Werkzeug 3.1.3
#    ----------- ----------------------------  7/24 [zstandard]
#    --------------- ------------------------  9/24 [werkzeug]
#     Uninstalling Werkzeug-3.1.3:
#    --------------- ------------------------  9/24 [werkzeug]
#       Successfully uninstalled Werkzeug-3.1.3
#    --------------- ------------------------  9/24 [werkzeug]
#    --------------- ------------------------  9/24 [werkzeug]
#    --------------- ------------------------  9/24 [werkzeug]
#    --------------- ------------------------  9/24 [werkzeug]
#    --------------- ------------------------  9/24 [werkzeug]
#    --------------- ------------------------  9/24 [werkzeug]
#    ---------------- ----------------------- 10/24 [soupsieve]
#   Attempting uninstall: numpy
#    ---------------- ----------------------- 10/24 [soupsieve]
#     Found existing installation: numpy 1.23.5
#    ---------------- ----------------------- 10/24 [soupsieve]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#     Uninstalling numpy-1.23.5:
#    -------------------- ------------------- 12/24 [numpy]
#       Successfully uninstalled numpy-1.23.5
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    -------------------- ------------------- 12/24 [numpy]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ----------------------- ---------------- 14/24 [future]
#    ------------------------- -------------- 15/24 [importlib-metadata]
#   Attempting uninstall: Flask
#    ------------------------- -------------- 15/24 [importlib-metadata]
#     Found existing installation: Flask 3.1.1
#    ------------------------- -------------- 15/24 [importlib-metadata]
#     Uninstalling Flask-3.1.1:
#    ------------------------- -------------- 15/24 [importlib-metadata]
#       Successfully uninstalled Flask-3.1.1
#    ------------------------- -------------- 15/24 [importlib-metadata]
#    -------------------------- ------------- 16/24 [Flask]
#    -------------------------- ------------- 16/24 [Flask]
#    -------------------------- ------------- 16/24 [Flask]
#    ---------------------------- ----------- 17/24 [beautifulsoup4]
#    ---------------------------- ----------- 17/24 [beautifulsoup4]
#    ---------------------------- ----------- 17/24 [beautifulsoup4]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------ --------- 18/24 [xarray]
#    ------------------------------- -------- 19/24 [Flask-Compress]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    --------------------------------- ------ 20/24 [dash]
#    ----------------------------------- ---- 21/24 [dash-daq]
#    ----------------------------------- ---- 21/24 [dash-daq]
#    ------------------------------------ --- 22/24 [dash-bootstrap-components]
#    ------------------------------------ --- 22/24 [dash-bootstrap-components]
#    ------------------------------------ --- 22/24 [dash-bootstrap-components]
#    ------------------------------------ --- 22/24 [dash-bootstrap-components]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    -------------------------------------- - 23/24 [dtale]
#    ---------------------------------------- 24/24 [dtale]
#
# Successfully installed Flask-3.0.3 Flask-Compress-1.17 beautifulsoup4-4.13.4 brotli-1.1.0 dash-2.18.2 dash-bootstrap-components-1.7.1 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-3.17.0 future-1.0.0 importlib-metadata-8.7.0 kaleido-0.2.1 lz4-4.4.4 numpy-2.3.0 retrying-1.3.4 soupsieve-2.7 squarify-0.4.4 strsimpy-0.2.1 werkzeug-3.0.6 xarray-2025.6.1 zipp-3.23.0 zstandard-0.23.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
#   DEPRECATION: Building 'dash-daq' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'dash-daq'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~oblib (C:\Users\agupta31\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.3.0 which is incompatible.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.5.1 which is incompatible.
# ydata-profiling 4.16.1 requires numpy<2.2,>=1.16.0, but you have numpy 2.3.0 which is incompatible.
# ydata-profiling 4.16.1 requires visions[type_image_path]<0.8.2,>=0.7.5, but you have visions 0.7.4 which is incompatible.

# %%
import pandas as pd
import dtale
import dtale.app as detale_app

detale_app.USE_clolab = True

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LT2407HZA001:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Feature: age                                 |██▌       | [ 25%]   34:32 -> (1:43:38 left)
# 2025-06-13 11:55:42,143 - INFO     - Executing shutdown due to inactivity...
# 2025-06-13 11:55:42,211 - INFO     - Executing shutdown...
# 2025-06-13 11:55:42,215 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
# 2025-06-13 14:56:26,989 - INFO     - Executing shutdown due to inactivity...
# 2025-06-13 14:56:27,079 - INFO     - Executing shutdown...
# 2025-06-13 14:56:27,084 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
